# %% [markdown]
# # Pandas Practice: Wine Quality Data

# %% [markdown]
# In this notebook you will practice the core Pandas skills introduced in `01_Introduction_to_Pandas.ipynb`: loading data, exploring a DataFrame, selecting rows and columns with bracket notation, `.loc[]`, and `.iloc[]`, filtering with boolean masks and `.query()`, grouping, sorting, and creating new columns.
#
# You will work with a dataset on the quality of red wines from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/wine+quality).

# %%
# --- Starter code: run this cell first ---
import pandas as pd

# The wine CSV uses semicolons as separators
df = pd.read_csv('../data/winequality-red.csv', delimiter=';')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# ## Part 1 — Exploring the Data

# %% [markdown]
# ### Challenge 1: Inspect the DataFrame
#
# Use the attributes and methods available on DataFrames to answer the following questions:
#
# - How many rows and columns are in the DataFrame?
#
# - What is the data type of each column?
#
# - How many non-null values are in each column?
#
# - Are all variables continuous, or are any categorical?
#
# - What are the min, mean, max, and median for all numeric columns?

# %%
# YOUR CODE HERE
df.shape
df.info()
df.describe()
#df.isna().sum()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ---
#
# ## Part 2 — Selecting and Filtering Data

# %% [markdown]
# ### Challenge 2: Select the first 10 rows of the `chlorides` column.

# %%
df['chlorides'].head(10)
# Out:
# 0    0.076
# 1    0.098
# 2    0.092
# 3    0.075
# 4    0.076
# 5    0.075
# 6    0.069
# 7    0.065
# 8    0.073
# 9    0.071
# Name: chlorides, dtype: float64

# %% [markdown]
# ### 3: Select the last 10 rows of the `chlorides` column.

# %%
df['chlorides'].tail(10)
# Out:
# 1589    0.073
# 1590    0.077
# 1591    0.089
# 1592    0.076
# 1593    0.068
# 1594    0.090
# 1595    0.062
# 1596    0.076
# 1597    0.075
# 1598    0.067
# Name: chlorides, dtype: float64

# %% [markdown]
# ### 4: Select rows at indices 264 through 282 of the `chlorides` and `density` columns.

# %%
df.loc[264:282, ['chlorides', 'density']]
# Out:
#      chlorides  density
# 264      0.064  0.99990
# 265      0.071  0.99680
# 266      0.096  1.00025
# 267      0.078  0.99730
# 268      0.077  0.99870
# 269      0.104  0.99960
# 270      0.087  0.99650
# 271      0.104  0.99960
# 272      0.071  0.99935
# 273      0.076  0.99735
# 274      0.088  0.99915
# 275      0.087  0.99650
# 276      0.077  0.99870
# 277      0.104  0.99960
# 278      0.073  0.99760
# 279      0.087  0.99910
# 280      0.071  0.99860
# 281      0.358  0.99720
# 282      0.067  0.99710

# %% [markdown]
# ### 5: Return all rows where the `chlorides` value is less than 0.10.

# %%
df[df['chlorides'] < 0.10]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1363 rows x 12 columns]

# %% [markdown]
# ### 6: Return all rows where `chlorides` is above the column mean.
#
# > Tip: don't hard-code the mean value — use a method to calculate it.

# %%
chlorides_mean = df['chlorides'].mean()
print (chlorides_mean)

df[df['chlorides'] > chlorides_mean]
# Out:
# 0.08746654158849279
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 10              6.7             0.580         0.08             1.8      0.097
# 12              5.6             0.615         0.00             1.6      0.089
# 13              7.8             0.610         0.29             1.6      0.114
# ...             ...               ...          ...             ...        ...
# 1558            6.9             0.630         0.33             6.7      0.235
# 1570            6.4             0.360         0.53             2.2      0.230
# 1578            6.8             0.670         0.15             1.8      0.118
# 1591            5.4             0.740         0.09             1.7      0.089
# 1594            6.2             0.600         0.08             2.0      0.090
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 10                   15.0                  65.0  0.99590  3.28       0.54
# 12                   16.0                  59.0  0.99430  3.58       0.52
# 13                    9.0                  29.0  0.99740  3.26       1.56
# ...                   ...                   ...      ...   ...        ...
# 1558                 66.0                 115.0  0.99787  3.22       0.56
# 1570                 19.0                  35.0  0.99340  3.37       0.93
# 1578                 13.0                  20.0  0.99540  3.42       0.67
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1594                 32.0                  44.0  0.99490  3.45       0.58
#
#       alcohol  quality
# 1         9.8        5
# 2         9.8        5
# 10        9.2        5
# 12        9.9        5
# 13        9.1        5
# ...       ...      ...
# 1558      9.5        5
# 1570     12.4        6
# 1578     11.3        6
# 1591     11.6        6
# 1594     10.5        5
#
# [474 rows x 12 columns]

# %% [markdown]
# ### 7: Return all rows where `pH` is greater than 3.0 and less than 3.5.

# %%
pH_res = df.query('pH > 3.0 and pH < 3.5')
print (pH_res, type(pH_res))
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 6               7.9              0.60         0.06             1.6      0.069
# 7               7.3              0.65         0.00             1.2      0.065
# ...             ...               ...          ...             ...        ...
# 1592            6.3              0.51         0.13             2.3      0.076
# 1593            6.8              0.62         0.08             1.9      0.068
# 1594            6.2              0.60         0.08             2.0      0.090
# 1596            6.3              0.51         0.13             2.3      0.076
# 1598            6.0              0.31         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 6                    15.0                  59.0  0.99640  3.30       0.46
# 7                    15.0                  21.0  0.99460  3.39       0.47
# ...                   ...                   ...      ...   ...        ...
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 6         9.4        5
# 7        10.0        7
# ...       ...      ...
# 1592     11.0        6
# 1593      9.5        6
# 1594     10.5        5
# 1596     11.0        6
# 1598     11.0        6
#
# [1382 rows x 12 columns] <class 'pandas.DataFrame'>

# %% [markdown]
# ### 8: From the result in Challenge 7, further filter to keep only rows where `residual sugar` is less than 2.0.

# %%
#pH_res.query("`residual sugar` < 2.0") 
pH_res[pH_res['residual sugar'] < 2.0]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2              0.28         0.56             1.9      0.075
# 6               7.9              0.60         0.06             1.6      0.069
# 7               7.3              0.65         0.00             1.2      0.065
# 10              6.7              0.58         0.08             1.8      0.097
# 13              7.8              0.61         0.29             1.6      0.114
# ...             ...               ...          ...             ...        ...
# 1569            6.2              0.51         0.14             1.9      0.056
# 1576            8.0              0.30         0.63             1.6      0.081
# 1578            6.8              0.67         0.15             1.8      0.118
# 1590            6.3              0.55         0.15             1.8      0.077
# 1593            6.8              0.62         0.08             1.9      0.068
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 6                    15.0                  59.0  0.99640  3.30       0.46
# 7                    15.0                  21.0  0.99460  3.39       0.47
# 10                   15.0                  65.0  0.99590  3.28       0.54
# 13                    9.0                  29.0  0.99740  3.26       1.56
# ...                   ...                   ...      ...   ...        ...
# 1569                 15.0                  34.0  0.99396  3.48       0.57
# 1576                 16.0                  29.0  0.99588  3.30       0.78
# 1578                 13.0                  20.0  0.99540  3.42       0.67
# 1590                 26.0                  35.0  0.99314  3.32       0.82
# 1593                 28.0                  38.0  0.99651  3.42       0.82
#
#       alcohol  quality
# 3         9.8        6
# 6         9.4        5
# 7        10.0        7
# 10        9.2        5
# 13        9.1        5
# ...       ...      ...
# 1569     11.5        6
# 1576     10.8        6
# 1578     11.3        6
# 1590     11.6        6
# 1593      9.5        6
#
# [388 rows x 12 columns]

# %% [markdown]
# ---
#
# ## Part 3 — Aggregating and Transforming Data

# %% [markdown]
# ### 9: Find the average amount of `chlorides` for each `quality` value.

# %%
#df.groupby('quality')['chlorides'].mean()
df.groupby('quality', as_index=False)['chlorides'].mean()
# Out:
#    quality  chlorides
# 0        3   0.122500
# 1        4   0.090679
# 2        5   0.092736
# 3        6   0.084956
# 4        7   0.076588
# 5        8   0.068444

# %% [markdown]
# ### 10: For wines where `pH` is between 3.0 and 4.0 (exclusive), find the average `alcohol` value grouped by `pH`.

# %%
df.query("3.0 < pH < 4.0").groupby('pH')['alcohol'].mean()
# Out:
# pH
# 3.01    11.320000
# 3.02    10.200000
# 3.03     9.633333
# 3.04     9.740000
# 3.05    10.050000
#           ...
# 3.74    11.500000
# 3.75    10.500000
# 3.78    12.400000
# 3.85    12.900000
# 3.90    12.950000
# Name: alcohol, Length: 75, dtype: float64

# %% [markdown]
# ### 11: For wines where `alcohol` is between 9.25 and 9.5, find the highest `residual sugar` value.

# %%
df.query("9.25 < alcohol < 9.5").groupby('alcohol')['residual sugar'].max()
# Out:
# alcohol
# 9.3     7.9
# 9.4    10.7
# Name: residual sugar, dtype: float64

# %% [markdown]
# ### 12: Create a new column called `total_acidity` that is the sum of `fixed acidity` and `volatile acidity`.

# %%
df = df.eval('`total_acidity` = `fixed acidity` + `volatile acidity`')
df.columns
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  total_acidity
# 0      9.4        5           8.10
# 1      9.8        5           8.68
# 2      9.8        5           8.56
# 3      9.8        6          11.48
# 4      9.4        5           8.10

# %% [markdown]
# ### 13: Find the average `total_acidity` for each `quality` value.

# %%
df.groupby('quality')['total_acidity'].mean()
# Out:
# quality
# 3    9.244500
# 4    8.473208
# 5    8.744295
# 6    8.844663
# 7    9.276281
# 8    8.990000
# Name: total_acidity, dtype: float64

# %% [markdown]
# ### 14: Find the 5 highest `density` values.

# %%
df.sort_values('density', ascending=False).head(5)
#df.nlargest(5, 'density')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1434           10.2             0.540         0.37            15.4      0.214
# 1435           10.2             0.540         0.37            15.4      0.214
# 442            15.6             0.685         0.76             3.7      0.100
# 554            15.5             0.645         0.49             4.2      0.095
# 555            15.5             0.645         0.49             4.2      0.095
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1434                 55.0                  95.0  1.00369  3.18       0.77
# 1435                 55.0                  95.0  1.00369  3.18       0.77
# 442                   6.0                  43.0  1.00320  2.95       0.68
# 554                  10.0                  23.0  1.00315  2.92       0.74
# 555                  10.0                  23.0  1.00315  2.92       0.74
#
#       alcohol  quality  total_acidity
# 1434      9.0        6         10.740
# 1435      9.0        6         10.740
# 442      11.2        7         16.285
# 554      11.1        5         16.145
# 555      11.1        5         16.145

# %% [markdown]
# ### 15: Find the 10 lowest `sulphates` values.

# %%
df.sort_values('sulphates', ascending=True).head(10)
#df.nsmallest(10,'sulphates')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 170             7.9             0.885         0.03            1.80      0.058
# 1287            8.0             0.600         0.08            2.60      0.056
# 1369            6.6             0.610         0.00            1.60      0.069
# 64              7.2             0.725         0.05            4.65      0.086
# 65              7.2             0.725         0.05            4.65      0.086
# 836             6.7             0.280         0.28            2.40      0.012
# 837             6.7             0.280         0.28            2.40      0.012
# 1347            7.2             0.655         0.03            1.80      0.078
# 1348            7.2             0.655         0.03            1.80      0.078
# 1234            7.1             0.750         0.01            2.20      0.059
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 170                   4.0                   8.0  0.99720  3.36       0.33
# 1287                  3.0                   7.0  0.99286  3.22       0.37
# 1369                  4.0                   8.0  0.99396  3.33       0.37
# 64                    4.0                  11.0  0.99620  3.41       0.39
# 65                    4.0                  11.0  0.99620  3.41       0.39
# 836                  36.0                 100.0  0.99064  3.26       0.39
# 837                  36.0                 100.0  0.99064  3.26       0.39
# 1347                  7.0                  12.0  0.99587  3.34       0.39
# 1348                  7.0                  12.0  0.99587  3.34       0.39
# 1234                 11.0                  18.0  0.99242  3.39       0.40
#
#       alcohol  quality  total_acidity
# 170       9.1        4          8.785
# 1287     13.0        5          8.600
# 1369     10.4        4          7.210
# 64       10.9        5          7.925
# 65       10.9        5          7.925
# 836      11.7        7          6.980
# 837      11.7        7          6.980
# 1347      9.5        5          7.855
# 1348      9.5        5          7.855
# 1234     12.8        6          7.850
